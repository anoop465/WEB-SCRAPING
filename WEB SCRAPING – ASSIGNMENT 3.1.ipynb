# %% [markdown]
# # Assingment

# %%
# Importing Libraries

import selenium 
import pandas as pd
import time 
from bs4 import BeautifulSoup

# Importing selenium Webdriver
from selenium import webdriver

#Importing required Exceptons which needs to handled

from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

from selenium.webdriver.common.by import By

# %% [markdown]
# 1. Write a python program which searches all the product under a particular product from www.amazon.in. The product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for guitars.

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.amazon.in/')

# %%
search_field_abc=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input")
search_field_abc.send_keys(input("Enter the Input: "))
# Out:
# Enter the Input: guitar

# %%
search_field_abc=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input")
search_field_abc.click()

# %% [markdown]
# 2. In the above question, now scrape the following details of each product listed in first 3 pages of your search results and save it in a data frame and csv. In case if any product has less than 3 pages in search results then scrape all the products available under that product name. Details to be scraped are: "Brand
# Name", "Name of the Product", "Price", "Return/Exchange", "Expected Delivery", "Availability" and
# “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
driver=webdriver.Chrome()
driver.get('https://www.amazon.in/')

# %%
search_field_abc=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input")
search_field_abc.send_keys('guitar')
search_field_abc=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input")
search_field_abc.click()
time.sleep(3)

# %%
#fetching url to open each job
aa_opening_url = []
start=0
end=3
for page in range(start,end):
    url = driver.find_elements(By.XPATH,'//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
    for i in url:
        aa_opening_url.append(i.get_attribute('href')) # to retrieve any link we use get_attribute
    next_button=driver.find_element(By.XPATH,'//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')
    next_button.click()
    time.sleep(5)

# %%
len(aa_opening_url)
# Out:
# 188

# %%
aa_opening_url
# Out:
# ['https://www.amazon.in/sspa/click?ie=UTF8&spc=MTo4NTgxMTk5NDM0Nzc2MDQ1OjE3MDc5ODI5NjA6c3BfYXRmOjMwMDAxNTUzNzk3OTIzMjo6MDo6&url=%2FKadence-Frontier-Acoustic-Guitar-Strings%2Fdp%2FB078GTJP5Y%2Fref%3Dsr_1_1%3Fkeywords%3Dguitar%26qid%3D1707982960%26sr%3D8-1-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1',
#  'https://www.amazon.in/sspa/click?ie=UTF8&spc=MTo4NTgxMTk5NDM0Nzc2MDQ1OjE3MDc5ODI5NjA6c3BfYXRmOjMwMDAxNTUwODk1NDEzMjo6MDo6&url=%2FKadence-Frontier-Acoustic-Guitar-Strings%2Fdp%2FB01GDZ46AA%2Fref%3Dsr_1_2%3Fkeywords%3Dguitar%26qid%3D1707982960%26sr%3D8-2-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1',
#  'https://www.amazon.in/sspa/click?ie=UTF8&spc=MTo4NTgxMTk5NDM0Nzc2MDQ1OjE3MDc5ODI5NjA6c3BfYXRmOjIwMDU3MTkzMDU2MjA0OjowOjo&url=%2FKadence-Slowhand-Premium-Acoustic-Instrument%2Fdp%2FB077SZ667X%2Fref%3Dsr_1_3%3Fkeywords%3Dguitar%26qid%3D1707982960%26sr%3D8-3-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1',
# ...

# %%
price=[]
Name=[]
Delivery=[]
Availability=[]
brand=[]
Return_Exchange=[]

for i in aa_opening_url:
    driver.get(i)
    time.sleep(5)
    try:
        aa= driver.find_element(By.XPATH,'//*[@id="corePrice_feature_div"]/div/div/span[1]/span[2]/span[2]') 
        price.append(aa.text)
    except NoSuchElementException :
        price.append('-')
    try:
        aa1= driver.find_element(By.XPATH,'//*[@id="productTitle"]') 
        Name.append(aa1.text)
    except NoSuchElementException :
        Name.append('-')
    try:
        aa2= driver.find_element(By.XPATH,'//*[@id="mir-layout-DELIVERY_BLOCK-slot-PRIMARY_DELIVERY_MESSAGE_LARGE"]/span/span[1]') 
        Delivery.append(aa2.text)
    except NoSuchElementException :
        Delivery.append('-')      
    try:
        aa3= driver.find_element(By.XPATH,'//*[@id="availability"]/span') 
        Availability.append(aa3.text)
    except NoSuchElementException :
        Availability.append('-')
    try:
        aa4= driver.find_element(By.XPATH,'//*[@id="productOverview_feature_div"]/div/table/tbody/tr[1]/td[2]/span') 
        brand.append(aa4.text)
    except NoSuchElementException :
        brand.append('-')
    try:
        aa5= driver.find_element(By.XPATH,'//*[@id="RETURNS_POLICY"]/span/div[2]/span') 
        Return_Exchange.append(aa5.text)
    except NoSuchElementException :
        Return_Exchange.append('-')

# %%
print(len(aa_opening_url),len(Name),len(price),len(Delivery),len(Availability))
# Out:
# 188 188 188 188 188

# %%
df5 = pd.DataFrame({'Brand_URL':aa_opening_url,'brand':brand,'Name':Name,'Price':price,'Delivery':Delivery,'Availability':Availability,'Return_Exchange':Return_Exchange})
df5
# Out:
#                                              Brand_URL         brand  \
# 0    https://www.amazon.in/sspa/click?ie=UTF8&spc=M...       Kadence
# 1    https://www.amazon.in/sspa/click?ie=UTF8&spc=M...       Kadence
# 2    https://www.amazon.in/sspa/click?ie=UTF8&spc=M...       Kadence
# 3    https://www.amazon.in/sspa/click?ie=UTF8&spc=M...        Henrix
# 4    https://www.amazon.in/Intern-INT-38C-Acoustic-...        Intern
# ..                                                 ...           ...
# 183  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...     blueberry
# 184  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...        Festra
# 185  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...  PS Signature
# 186  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...  PS Signature
# 187  https://aax-eu.amazon.in/x/c/RHIxC8fQPr-BNT2P6...       natural
#
#                                                   Name  Price  \
# 0    Kadence rosewood Guitar Frontier Series, Elect...  5,499
# ...

# %% [markdown]
# 3. Write a python program to access the search bar and search button on images.google.com and scrape 10 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’.

# %%
driver=webdriver.Chrome()
driver.get('https://www.google.in/')

# %%
designation=driver.find_element(By.CLASS_NAME,"gLFyf")
designation.send_keys('Cake')

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/form/div[1]/div[1]/div[4]/center/input[1]")
search.click()

# %%
search=driver.find_element(By.XPATH,"/html/body/div[5]/div/div[4]/div/div/div[1]/div[1]/div/div[1]/div/div/div/div[1]/a[1]/div/span")
search.click()

# %%
for i in range(20):
    driver.execute_script("window.scrollBy(0,500)")

for i in range(20):
    driver.execute_script("window.scrollBy(0,500)")
response=[]
images = driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
img_urls = []

for image in images:
    source=image.get_attribute('src')
    if source is not None:
        if(source[0:4]=='http'):
            img_urls.append(source)
            
for i in range(len(img_urls)):
    if i >10:
        breakBy.XPATH,
    print("Downloading {0} of {1} images".format(i, 10)) 
    response=requests.get(img_urls[i])
    file = open(r"C:\Users\admin\OneDrive\Desktop\Review -Feb-2024\Format\Done"+str(i)+".jpg","wb")
    file.write(response.content)
    exit()
# Out:
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3536\3539696915.py in <module>
#      16 for i in range(len(img_urls)):
#      17     if i >10:
# ---> 18         breakBy.XPATH,
#      19     print("Downloading {0} of {1} images".format(i, 10))
#      20     response=requests.get(img_urls[i])
#
# NameError: name 'breakBy' is not defined

# %% [markdown]
# 4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”,
# “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
driver=webdriver.Chrome()
driver.get('https://www.flipkart.com/')

# %%
Glass=driver.find_element(By.CLASS_NAME,"Pke_EE")
Glass.send_keys('pixel 4A')

# %%
search=driver.find_element(By.CLASS_NAME,"_2iLD__")
search.click()

# %%
phone_url = []
start=0
end=1
for page in range(start,end):
    url = driver.find_elements(By.XPATH,'//a[@class="_1fQZEK"]')
    for i in url:
        phone_url.append(i.get_attribute('href')) # to retrieve any link we use get_attribute

# %%
len(phone_url)
# Out:
# 24

# %%
phone_url
# Out:
# ['https://www.flipkart.com/realme-c53-champion-gold-64-gb/p/itm5df90168ecd05?pid=MOBGQY939DG9GBQ8&lid=LSTMOBGQY939DG9GBQ8AQQV4I&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&spotlightTagId=BestsellerId_tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=Search&iid=347e3b0c-fd55-474e-8e15-37e9d5c7afd5.MOBGQY939DG9GBQ8.SEARCH&ppt=sp&ppn=sp&ssid=64wnzgjn0w0000001708023412970&qH=9b26a23b2cff510d',
#  'https://www.flipkart.com/motorola-edge-40-nebula-green-256-gb/p/itmaa0bf9c327a2b?pid=MOBGKHNBTVZZU8PH&lid=LSTMOBGKHNBTVZZU8PHORDDSI&marketplace=FLIPKART&q=pixel+4A&store=tyy%2F4io&srno=s_1_2&otracker=search&otracker1=search&fm=organic&iid=347e3b0c-fd55-474e-8e15-37e9d5c7afd5.MOBGKHNBTVZZU8PH.SEARCH&ppt=hp&ppn=homepage&ssid=64wnzgjn0w0000001708023412970&qH=9b26a23b2cff510d',
# ...

# %%
Brand_Name=[]
Smartphone_name=[]
Colour=[]
Price=[]
Display_Size=[]
Storage_ROM_RAM=[]
Camera_P_S=[]
Battery_Capacity=[]

for i in phone_url:
    driver.get(i)
    time.sleep(5)
    try:
        aa= driver.find_element(By.XPATH,'//*[@id="container"]/div/div[3]/div[1]/div[2]/div[2]/div/div[4]/div[1]/div/div[1]') 
        Price.append(aa.text)
    except NoSuchElementException :
        Price.append('-')
    try:
        aa1= driver.find_element(By.XPATH,'//*[@id="container"]/div/div[3]/div[1]/div[2]/div[7]/div[1]/div/div[2]/ul/li[2]') 
        Display_Size.append(aa1.text)
    except NoSuchElementException :
        Display_Size.append('-')
    try:
        aa2= driver.find_element(By.XPATH,'//*[@id="container"]/div/div[3]/div[1]/div[2]/div[7]/div[1]/div/div[2]/ul/li[1]') 
        Storage_ROM_RAM.append(aa2.text)
    except NoSuchElementException :
        Storage_ROM_RAM.append('-')
    try:
        aa3= driver.find_element(By.XPATH,'//*[@id="container"]/div/div[3]/div[1]/div[2]/div[7]/div[1]/div/div[2]/ul/li[3]') 
        Camera_P_S.append(aa3.text)
    except NoSuchElementException :
        Camera_P_S.append('-')    
    try:
        aa4= driver.find_element(By.XPATH,'//*[@id="container"]/div/div[3]/div[1]/div[2]/div[7]/div[1]/div/div[2]/ul/li[4]') 
        Battery_Capacity.append(aa4.text)
    except NoSuchElementException :
        Battery_Capacity.append('-')
    try:
        aa5= driver.find_element(By.XPATH,'//*[@id="container"]/div/div[3]/div[1]/div[2]/div[8]/div[4]/div/div[2]/div/div[1]/table/tbody/tr[4]/td[2]/ul/li') 
        Colour.append(aa5.text)
    except NoSuchElementException :
        Colour.append('-')
    try:
        aa6= driver.find_element(By.XPATH,'//*[@id="container"]/div/div[3]/div[1]/div[2]/div[8]/div[4]/div/div[2]/div/div[1]/table/tbody/tr[3]/td[2]/ul/li') 
        Smartphone_name.append(aa6.text)
    except NoSuchElementException :
        Smartphone_name.append('-')
    try:
        aa7= driver.find_element(By.XPATH,'//*[@id="container"]/div/div[3]/div[1]/div[2]/div[1]/div[1]/div/div[4]') 
        Brand_Name.append(aa7.text)
    except NoSuchElementException :
        Brand_Name.append('-')

# %%
print(len(Brand_Name),len(Smartphone_name),len(Colour),len(Price),len(Display_Size),len(Storage_ROM_RAM),len(Camera_P_S),len(Battery_Capacity))
# Out:
# 24 24 24 24 24 24 24 24

# %%
df6=pd.DataFrame({'Brand':Brand_Name,'Smartphone_name':Smartphone_name,'Colour':Colour,'Price':Price,'Display_Size':Display_Size,'Storage_ROM_RAM':Storage_ROM_RAM,'Camera_P_S':Camera_P_S,'Battery_Capacity':Battery_Capacity,})
df6
# Out:
#                Brand Smartphone_name          Colour    Price  \
# 0     realme Mobiles               -               -   ₹8,999
# 1   MOTOROLA Mobiles               -               -  ₹26,999
# 2   MOTOROLA Mobiles               -               -  ₹26,999
# 3     realme Mobiles               -               -   ₹9,499
# 4     Google Mobiles               -               -  ₹40,999
# 5     Google Mobiles               -               -  ₹40,999
# 6    SAMSUNG Mobiles               -               -  ₹29,999
# 7    SAMSUNG Mobiles               -               -  ₹29,999
# 8     Google Mobiles               -               -        -
# 9     Google Mobiles               -               -        -
# 10    Google Mobiles               -               -        -
# 11    Google Mobiles               -               -        -
# 12      POCO Mobiles           F4 5G     Night Black  ₹21,999
# 13    Google Mobiles               -               -  ₹46,999
# ...

# %% [markdown]
# 5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps

# %%
import re

# %%
driver=webdriver.Chrome()
driver.get("https://www.google.com/maps")

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/div[8]/div[3]/div[1]/div[1]/div/div[2]/form/input")
location.send_keys('Delhi')

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/div[8]/div[3]/div[1]/div[1]/div/div[2]/div[1]/button/span")
search.click()

# %%
    try:
        url_string = driver.current_url
        print("URL Extracted", url_string)
        lat_lng = re.findall(r'@(.*)data',url_string)
    except NoSuchElementException :
        Brand_Name.append('-')
# Out:
# URL Extracted https://www.google.com/maps/place/Delhi/@28.6440836,77.0932313,10z/data=!3m1!4b1!4m6!3m5!1s0x390cfd5b347eb62d:0x37205b715389640!8m2!3d28.7040592!4d77.1024902!16zL20vMDlmMDc?entry=ttu

# %%
re.findall(r'\d+', "https://www.google.com/maps/place/Delhi/@28.6440836,77.0932313,10z/data=!3m1!4b1!4m6!3m5!1s0x390cfd5b347eb62d:0x37205b715389640!8m2!3d28.7040592!4d77.1024902!16zL20vMDlmMDc?entry=ttu")
# Out:
# ['28',
#  '6440836',
#  '77',
#  '0932313',
#  '10',
#  '3',
#  '1',
#  '4',
#  '1',
#  '4',
#  '6',
#  '3',
#  '5',
#  '1',
#  '0',
#  '390',
#  '5',
#  '347',
#  '62',
#  '0',
#  '37205',
#  '715389640',
#  '8',
#  '2',
#  '3',
#  '28',
#  '7040592',
#  '4',
#  '77',
#  '1024902',
#  '16',
#  '20']

# %% [markdown]
# 6. Write a program to scrap all the available details of best gaming laptops from digit.in.

# %%
driver=webdriver.Chrome()
driver.get("https://www.digit.in/")

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[2]/div/nav/ul/li[3]/a")
search.click()

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/div/div[2]/div[1]/div[3]/div[5]/p/a")
search.click()

# %%
laptop=[]
laptop_tags=driver.find_elements(By.XPATH,'//div[@class="rh_gr_top_middle mb10 colored_rate_bar"]')
for i in laptop_tags[0:10]:
    aa=i.text
    laptop.append(aa)

# %%
laptop
# Out:
# ['ASUS Vivobook K15 OLED Ryzen 5-5500U (KM513UA-L512WS)',
#  'realme Book Prime 11th Gen Core i5-11320H (CloudPro002)',
#  'ASUS Vivobook S14 OLED S3402ZA-KM501WS 12th Gen Core i5-12500H',
#  'ASUS Vivobook Pro 16 OLED 13th Gen Core i5-13500H (K6602VU-LZ542WS)',
#  'Lenovo Yoga Slim 7i Carbon 12th Gen Core i7-1260P (82U90080IN)',
#  'Apple MacBook Pro MNEQ3HN/A (2022)',
#  'Samsung Galaxy Book3 Pro NP940XFG-KC5IN 13th Gen Core i7-1360P',
#  'Apple MacBook Pro (MK1F3HN/A)']

# %% [markdown]
# 7. Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
driver=webdriver.Chrome()
driver.get("https://www.forbes.com/")

# %%
search1=driver.find_element(By.CLASS_NAME,"_8FT-x3t4")
search1.click()

# %%
search2=driver.find_element(By.CLASS_NAME,"mpBfVZz3")
search2.click()

# %%
search3=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/header/div[1]/div[1]/div[2]/ul/li[2]/div[2]/div[3]/ul/li[1]/a")
search3.click()

# %% [markdown]
# 8. Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted from any YouTube Video.

# %%
driver=webdriver.Chrome()
driver.get("https://www.youtube.com/watch?v=f1h6NZYem0o")

# %%
comment=[]
comment_time=[]

# %%
for i in range(10):
    driver.execute_script("window.scrollBy(0,10)")
time_tags=driver.find_elements(By.XPATH,'//*[@id="header-author"]/yt-formatted-string/a')
for i in time_tags:
    time=i.text
    comment_time.append(time)

for i in range(10):
    driver.execute_script("window.scrollBy(0,10)")
comment_tags=driver.find_elements(By.XPATH,'//*[@id="content-text"]/span[1]')
for i in comment_tags:
    cc=i.text
    comment.append(cc)

# %%
print(len(comment),len(comment_time))
# Out:
# 328 510

# %%
df6=pd.DataFrame({'comment':comment,'comment_time':comment_time})
df6
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9968\605036854.py in <module>
# ----> 1 df6=pd.DataFrame({'comment':comment,'comment_time':comment_time})
#       2 df6
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     634         elif isinstance(data, dict):
#     635             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637         elif isinstance(data, ma.MaskedArray):
#     638             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     500         # TODO: can we get rid of the dt64tz special case above?
#     501
# ...

# %%
for i in range(500):
    driver.execute_script("window.scrollBy(0,500)")
time_tags=driver.find_elements(By.XPATH,'//*[@id="header-author"]/yt-formatted-string/a')
for i in time_tags:
    time=i.text
    comment_time.append(time)

for i in range(500):
    driver.execute_script("window.scrollBy(0,500)")
comment_tags=driver.find_elements(By.XPATH,'//*[@id="content-text"]/span[1]')
for i in comment_tags:
    cc=i.text
    comment.append(cc)

# %%
df6=pd.DataFrame({'comment':comment,'comment_time':comment_time})
df6
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9968\605036854.py in <module>
# ----> 1 df6=pd.DataFrame({'comment':comment,'comment_time':comment_time})
#       2 df6
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     634         elif isinstance(data, dict):
#     635             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637         elif isinstance(data, ma.MaskedArray):
#     638             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     500         # TODO: can we get rid of the dt64tz special case above?
#     501
# ...

# %% [markdown]
# 9. Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews, overall reviews, privates from price, dorms from price, facilities and property description.

# %%
# Importing Libraries

import selenium 
import pandas as pd
import time 
from bs4 import BeautifulSoup

# Importing selenium Webdriver
from selenium import webdriver

#Importing required Exceptons which needs to handled

from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

from selenium.webdriver.common.by import By

# %%
driver=webdriver.Chrome()

# %%
#fetching url

driver.get('https://www.hostelworld.com/')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[3]/div/div/div[2]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/input")
location.send_keys('London')

# %%
search=driver.find_element(By.XPATH,"/html/body/div[3]/div/div/div[2]/div[2]/div[2]/div/div/div/div[1]/div[2]/div/ul/li[2]/button/div[2]/div[1]")
search.click()

# %%
search1=driver.find_element(By.XPATH,"/html/body/div[3]/div/div/div[2]/div[2]/div[2]/div/div/div/div[5]/button[1]")
search1.click()

# %%
hotel_url = []
start=0
end=1
for page in range(start,end):
    url = driver.find_elements(By.XPATH,'//a[@class="property-card-container"]')
    for i in url:
        hotel_url.append(i.get_attribute('href')) # to retrieve any link we use get_attribute

# %%
hotel_url
# Out:
# ["https://www.hostelworld.com/pwa/hosteldetails.php/Wombat's%20City%20Hostel%20London/London/88047?from=2024-02-17&to=2024-02-20&guests=2",
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Palmers%20Lodge%20-%20Swiss%20Cottage/London/14348?from=2024-02-17&to=2024-02-20&guests=2',
#  "https://www.hostelworld.com/pwa/hosteldetails.php/St%20Christopher's%20Village/London/502?from=2024-02-17&to=2024-02-20&guests=2"]

# %%
len(hotel_url)
# Out:
# 3

# %%
Hotal_name=[]
distance=[]
rating=[]
reviews=[]
private_price=[]
dorms_fromprice=[]
facilities=[]
property_description=[]


for i in hotel_url:
    driver.get(i)
    time.sleep(5)
    try:
        aa= driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div[2]/div[2]/div[1]/div/div/div[4]/div[1]/a/a/div[2]/div[2]/span[2]') 
        distance.append(aa.text)
    except NoSuchElementException :
        distance.append('-')
    try:
        aa1= driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div[2]/section/div[4]/div/div[1]/h1/div') 
        Hotal_name.append(aa1.text)
    except NoSuchElementException :
        Hotal_name.append('-')    
    try:
        aa2= driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div[2]/section/div[8]/div/div[1]/div[1]/div[1]') 
        rating.append(aa2.text)
    except NoSuchElementException :
        rating.append('-')
    try:
        aa3= driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div[2]/section/div[8]/div/div[1]/div[1]/div[2]/div[2]') 
        reviews.append(aa3.text)
    except NoSuchElementException :
        reviews.append('-')
    try:
        aa4= driver.find_element(By.XPATH,'//*[@id="rate-383082-price"]') 
        private_price.append(aa4.text)
    except NoSuchElementException :
        private_price.append('-')
    try:
        aa5= driver.find_element(By.XPATH,'//*[@id="rate-151291-price"]') 
        dorms_fromprice.append(aa5.text)
    except NoSuchElementException :
        dorms_fromprice.append('-')
    try:
        aa6= driver.find_element(By.XPATH,'//*[@id="facilities-section"]/div/ul/li[1]/ul') 
        facilities.append(aa6.text)
    except NoSuchElementException :
        facilities.append('-')
    try:
        aa7= driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div[2]/section/div[8]/div/div[2]/div[3]/div/div[2]') 
        property_description.append(aa7.text)
    except NoSuchElementException :
        property_description.append('-')

# %%
Hotal_name=[]
distance=[]
rating=[]
reviews=[]
private_price=[]
dorms_fromprice=[]
facilities=[]
property_description=[]

# %%
print(len(Hotal_name),len(distance),len(rating),len(reviews),len(private_price),len(dorms_fromprice))
# Out:
# 33 30 33 30 43 40

# %%
df6=pd.DataFrame({'Hotal_name':Hotal_name,'distance':distance,'rating':rating,'reviews':reviews,'private_price':private_price,'dorms_fromprice':dorms_fromprice,'facilities':facilities,'property_description':property_description,})
df6
# Out:
#                                  Hotal_name distance rating  \
# 0               Wombat's City Hostel London        -    9.1
# 1             Palmers Lodge - Swiss Cottage        -    8.8
# 2                  St Christopher's Village        -    7.8
# 3               Wombat's City Hostel London        -    9.1
# 4             Palmers Lodge - Swiss Cottage        -    8.8
# 5                  St Christopher's Village        -    7.8
# 6                          NX London Hostel        -    8.9
# 7                      Urbany Hostel London        -    9.5
# 8                       Onefam Notting Hill        -    9.6
# 9                          Generator London        -    7.5
# 10                          Onefam Waterloo        -    9.6
# 11                          Astor Hyde Park        -    8.2
# 12        Safestay London Elephant & Castle        -    7.3
# 13                         Astor Museum Inn        -    8.4
# 14                       No.8 Seven Sisters        -    7.8
# ...
